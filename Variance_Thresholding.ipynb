# %% [markdown]
# <a href="https://colab.research.google.com/github/aarthyviven/DataScienceNotebook/blob/main/Variance_Thresholding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Variance Thresholding

# %%
from sklearn.feature_selection import VarianceThreshold
import numpy as np
X = np.array([
    [0, 2, 0, 3],
    [0, 1, 4, 3],
    [0, 1, 1, 3],
    [0, 1, 0, 3],
    [0, 1, 3, 3]
])
selector = VarianceThreshold()
X_sele = selector.fit_transform(X)
print("Original shape:", X.shape)
print("Reduced shape:", X_sele.shape)
# Print the reduced array
print("Reduced array:\n", X_sele)
# Out:
# Original shape: (5, 4)
# Reduced shape: (5, 2)
# Reduced array:
#  [[2 0]
#  [1 4]
#  [1 1]
#  [1 0]
#  [1 3]]
